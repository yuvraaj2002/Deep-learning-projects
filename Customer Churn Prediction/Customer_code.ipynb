# %% [markdown]
# # Importing the libraries

# %%
# For data analysis and manipulation
import pandas as pd
import numpy as np

# For data visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# For data processing and cleaning
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="pandas")

# For creating an artificial neural network
import keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
import keras_tuner as kt

# %%
# Reading the data from the csv file using read_csv() method
df = pd.read_csv('Churn_Modelling.csv')

# %% [markdown]
# # Exploratory data analysis

# %%
# Checking any 5 random rows from the dataframe
df.sample(5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 7424       7425    15625501       Wall          570   Germany    Male   38
# 5628       5629    15665168  Calabrese          681   Germany  Female   44
# 9525       9526    15699415      Lewis          618    France  Female   46
# 1052       1053    15623471    Marcelo          607   Germany    Male   38
# 9586       9587    15786418       Chiu          546    France  Female   20
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7424       1  127201.58              1          1               0
# 5628       3  105206.70              2          1               1
# 9525       6  150213.71              1          1               0
# 1052       3   98205.77              1          1               0
# 9586       6       0.00              1          0               1
#
#       EstimatedSalary  Exited
# 7424        147168.28       1
# 5628        163558.36       0
# 9525        120668.46       1
# 1052        176318.27       0
# 9586         20508.85       0

# %%
# Checking the shape of the dataframe
df.shape
# Out:
# (10000, 14)

# %%
# Checking the datatype of the features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Optimizing the memory occupied by using the appropriate datatypes
int_cols = df.select_dtypes(include=np.int64)
int_cols = int_cols.columns
df[int_cols] = df[int_cols].astype(np.int32)

float_cols = df.select_dtypes(include=np.float64)
float_cols = float_cols.columns
df[float_cols] = df[float_cols].astype(np.float32)

# %%
# Let's get some descriptive information about our dataframe
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.890625       1.530200      0.70550        0.515100
# std     62397.406250       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.539062       1.000000      1.00000        1.000000
# 75%    127644.238281       2.000000      1.00000        1.000000
# max    250898.093750       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.234375      0.203700
# std       57510.492188      0.402769
# min          11.580000      0.000000
# 25%       51002.109375      0.000000
# 50%      100193.914062      0.000000
# 75%      149388.253906      0.000000
# max      199992.484375      1.000000

# %%
# Let's check the percentage of null values
df.isnull().mean()*100
# Out:
# RowNumber          0.0
# CustomerId         0.0
# Surname            0.0
# CreditScore        0.0
# Geography          0.0
# Gender             0.0
# Age                0.0
# Tenure             0.0
# Balance            0.0
# NumOfProducts      0.0
# HasCrCard          0.0
# IsActiveMember     0.0
# EstimatedSalary    0.0
# Exited             0.0
# dtype: float64

# %%
# Let's check if there are any duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# Distribution of data in target variable
ex = (0,0.2)
df['Exited'].value_counts().plot(kind='pie',autopct='%.2f',explode= ex)
# Out:
# <AxesSubplot:ylabel='Exited'>

# %%
# Let's plot barplots to find out answer to the questions
fig,ax = plt.subplots(1,2,figsize =(15,4.5))

temp1 = df.groupby('Gender')['Exited'].sum()
temp2 = df.groupby('NumOfProducts')['Exited'].sum()

sns.barplot(x = temp1.index , y = temp1,saturation=2,ax = ax[0]).set(title='Male Vs Female comparsion regarding exits')
sns.barplot(x = temp2.index , y = temp2,saturation=2,ax = ax[1]).set(title='Number of products comparsion regarding exits')
plt.show()

# %%
# Let's plot barplots to find out answer to the questions
fig,ax = plt.subplots(1,3,figsize =(17,4.5))

temp3 = df.groupby('IsActiveMember')['Exited'].sum()
temp4 = df.groupby('Tenure')['Exited'].sum()
temp5 = df.groupby('Geography')['Exited'].sum()

sns.barplot(x = ['No','Yes'] , y = temp3,saturation=2,ax = ax[0]).set(title='Active member comparsion regarding exits')
sns.barplot(x = temp4.index , y = temp4,saturation=2,ax = ax[1]).set(title='Tenure comparsion regarding exits')
sns.barplot(x = temp5.index , y = temp5,saturation=2,ax = ax[2]).set(title='Geography comparsion regarding exits')
plt.show()

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Let's visualize the distribution of some numerical features so that we could decide whether to use IQR or z SCORE method for detecting and dealing with outliers

# %%
fig,ax = plt.subplots(2,2,figsize=(16,7))
fig.subplots_adjust(hspace=0.5, wspace=0.2)

sns.kdeplot(df['CreditScore'],shade=True,ax = ax[0][0]).set(title='Distribution of credit Score')
ax[0][0].axvline(df['CreditScore'].mean(),color='red',label='mean')
ax[0][0].axvline(df['CreditScore'].median(),color='blue',label='median')
ax[0][0].axvline(df['CreditScore'].mode().values[0],color='green',label='mode')
ax[0][0].legend()
sns.boxplot(x = df['CreditScore'],ax = ax[0][1]).set(title='Boxplot of Credit Score')

sns.kdeplot(df['Age'],shade=True,ax = ax[1][0]).set(title='Distribution of Age')
ax[1][0].axvline(df['Age'].mean(),color='red',label='mean')
ax[1][0].axvline(df['Age'].median(),color='blue',label='median')
ax[1][0].axvline(df['Age'].mode().values[0],color='green',label='mode')
sns.boxplot(x = df['Age'],ax = ax[1][1]).set(title='Boxplot of Age')
ax[1][0].legend()

plt.show()

# %%
fig,ax = plt.subplots(2,2,figsize=(16,7))
fig.subplots_adjust(hspace=0.5, wspace=0.2)

sns.kdeplot(df['Balance'],shade=True,ax = ax[0][0]).set(title='Distribution of Balance')
ax[0][0].axvline(df['Balance'].mean(),color='red',label='mean')
ax[0][0].axvline(df['Balance'].median(),color='blue',label='median')
ax[0][0].axvline(df['Balance'].mode().values[0],color='green',label='mode')
sns.boxplot(x = df['Balance'],ax = ax[0][1]).set(title='Boxplot of Balance')
ax[0][0].legend()


sns.kdeplot(df['EstimatedSalary'],shade=True,ax = ax[1][0]).set(title='Distribution of Estimated Salary')
ax[1][0].axvline(df['EstimatedSalary'].mean(),color='red',label='mean')
ax[1][0].axvline(df['EstimatedSalary'].median(),color='blue',label='median')
ax[1][0].axvline(df['EstimatedSalary'].mode().values[0],color='green',label='mode')
sns.boxplot(x = df['EstimatedSalary'],ax = ax[1][1]).set(title='Boxplot of Estimated Salary')
ax[1][0].legend()
plt.show()

# %% [markdown]
# Since none of the above feature is having normal or sort of normal distribution thus we will use inter quartile range method for the detecting and handing outliers.
#
# Also as we can clearly see that Age and Credit Score features have some outliers and now to handle these outliers we can either remove them or we can simply cap them. So we will do and compare the distribution before and after remvoing/capping outliers with respect to the original distribution

# %%
# Let's create 2 copies 
cap_df = df[['Age','CreditScore']].copy()
remove_df = df[['Age','CreditScore']].copy()

# %%
# Creating function for finding upper and lower limit of the feature
def find_ul_ll(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    IQR = q3-q1
    Upper_lmt = q3 + (1.5*IQR)
    Lower_lmt = q1 - (1.5*IQR)
    return [Upper_lmt,Lower_lmt]

# %%
# Let's cap the outliers
for col in cap_df.columns:
    lmts = find_ul_ll(cap_df[col])
    cap_df[col] = np.where(cap_df[col] > lmts[0],lmts[0], 
                           np.where(cap_df[col]<lmts[1],lmts[1],cap_df[col]))

# %%
# Let's find limits to remove the outliers
lmts_age = find_ul_ll(remove_df['Age'])
lmts_creditsc = find_ul_ll(remove_df['CreditScore'])

remove_df = remove_df[remove_df['Age'] < lmts_age[0]]
remove_df = remove_df[remove_df['CreditScore'] > lmts_creditsc[1]]

# %%
# Let's now visualize the change in distribution after capping/remvoing outliers
fig,ax = plt.subplots(1,2,figsize=(17,3.5))
fig.subplots_adjust(hspace=0.5, wspace=0.2)

sns.kdeplot(df['Age'],shade=True,ax = ax[0],color='green',label='Original')
sns.kdeplot(cap_df['Age'],shade=True,ax = ax[0],color='blue',label='After capping')
sns.kdeplot(remove_df['Age'],shade=True,ax = ax[0],color='red',label='After removal')
ax[0].legend()

sns.kdeplot(df['CreditScore'],shade=True,ax = ax[1],color='green',label='Original')
sns.kdeplot(cap_df['CreditScore'],shade=True,ax = ax[1],color='blue',label='After capping')
sns.kdeplot(remove_df['CreditScore'],shade=True,ax = ax[1],color='red',label='After removal')
ax[1].legend()

plt.show()

# %% [markdown]
# In Age feature the disitribution is chaning a lot after capping the outliers, thus we will go on with removing the outliers whereas in case of Credit Score we will cap the outilers because the distribution is not chaning a lot after removing or capping.

# %%
# Removing outiers from the Age feature in the original dataframe
df = df[df['Age'] < lmts_age[0]]

# Capping the outliers in the Credit Score feature of original dataframe
df['CreditScore'] = np.where(df['CreditScore']>lmts_creditsc[0],lmts_creditsc[0],
                             np.where(df['CreditScore']<lmts_creditsc[1],lmts_creditsc[1],df['CreditScore']))

# %% [markdown]
# # Feature engineering
#
# - Feature transformation
# - Feature selection
# - Feature extraction
# - Feature scaling

# %%
# Let's drop unnecessary features
df.drop(['RowNumber','CustomerId','Surname','Geography'],axis=1,inplace=True)

# %%
# Train test split 
y = df['Exited']
X = df.drop(['Exited'],axis=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3, random_state=42,stratify=y)

# %%
# instantiate the OneHotEncoder object
ohe = OneHotEncoder(drop='first',dtype = np.int32)

# fit and transform the training data Gender column and store the results in a new DataFrame
X_train_gender_ohe = pd.DataFrame(ohe.fit_transform(X_train[['Gender']]).toarray(), columns=ohe.get_feature_names(['Gender']))

# transform the test data Gender column and store the results in a new DataFrame
X_test_gender_ohe = pd.DataFrame(ohe.transform(X_test[['Gender']]).toarray(), columns=ohe.get_feature_names(['Gender']))

# drop the original Gender column from both the training and test datasets
X_train = X_train.drop(['Gender'], axis=1)
X_test = X_test.drop(['Gender'], axis=1)
# Out:
# C:\Users\YUVRAJ\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\YUVRAJ\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Resetting the index
X_train.reset_index(inplace=True,drop=True)
X_test.reset_index(inplace=True,drop=True)
X_train_gender_ohe.reset_index(inplace=True,drop=True)
X_test_gender_ohe.reset_index(inplace=True,drop=True)

# %%
# concatenate the one-hot-encoded Gender columns to the training and test datasets
X_train = pd.concat([X_train, X_train_gender_ohe], axis=1)
X_test = pd.concat([X_test, X_test_gender_ohe], axis=1)

# %%
# Let's plot a heatmap to visualize the correlation between the variables
fig,ax = plt.subplots(figsize=(13,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# Let's create an object of MinMax scaler
scaler = MinMaxScaler()

# %%
# Let's normalize the values
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (6712, 9)

# %% [markdown]
# # Neural network training

# %%
# Function to create a model
def build_model(hp):
    
    model = Sequential() 
    
    count = 0
    # For number of layers
    for i in range(hp.Int('layers',min_value=1,max_value=10)):
        if count == 0:
            model.add( # Means input layer
                Dense(hp.Int('neurons'+str(i),min_value=8,max_value=128)
                ,activation = hp.Choice('activation'+str(i),values = ['relu','tanh','sigmoid']),input_dim = 9)
            )
        else:
            model.add( 
                Dense(hp.Int('neurons'+str(i),min_value=8,max_value=128)
                ,activation = hp.Choice('activation'+str(i),values = ['relu','tanh','sigmoid']))
            )
        count = count+1
        
        
    # Output layer
    model.add(Dense(1,activation='sigmoid'))
        
    # Compiling the model
    model.compile(optimizer = hp.Choice('optimiers',values = ['adam','sgd','rmsprop','adadelta']), loss = 'binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Creating an tuner object of RandomSearch class
tuner = kt.RandomSearch(build_model,objective='val_accuracy',max_trials=5)

# %%
# Let's now search best hyper parameters
tuner.search(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Trial 5 Complete [00h 00m 07s]
# val_accuracy: 0.7990962862968445
#
# Best val_accuracy So Far: 0.8439346551895142
# Total elapsed time: 00h 00m 52s
# INFO:tensorflow:Oracle triggered exit

# %%
# Extracting best optimizer
tuner.get_best_hyperparameters()[0].values
# Out:
# {'layers': 8,
#  'neurons0': 55,
#  'activation0': 'tanh',
#  'optimiers': 'rmsprop',
#  'neurons1': 54,
#  'activation1': 'tanh',
#  'neurons2': 89,
#  'activation2': 'tanh',
#  'neurons3': 69,
#  'activation3': 'relu',
#  'neurons4': 39,
#  'activation4': 'sigmoid',
#  'neurons5': 78,
#  'activation5': 'tanh',
#  'neurons6': 62,
#  'activation6': 'tanh',
#  'neurons7': 8,
#  'activation7': 'relu'}

# %%
# Extracting model
model = tuner.get_best_models(num_models=1)[0]

# Let's check the detailed summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 55)                550
#
#  dense_1 (Dense)             (None, 54)                3024
#
#  dense_2 (Dense)             (None, 89)                4895
#
#  dense_3 (Dense)             (None, 69)                6210
#
#  dense_4 (Dense)             (None, 39)                2730
#
#  dense_5 (Dense)             (None, 78)                3120
#
#  dense_6 (Dense)             (None, 62)                4898
#
#  dense_7 (Dense)             (None, 8)                 504
#
#  dense_8 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 25,940
# Trainable params: 25,940
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# Train the neural network
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3000, initial_epoch =6, callbacks=callback)
# Out:
# Epoch 7/3000
# 210/210 [==============================] - 4s 13ms/step - loss: 0.3676 - accuracy: 0.8503 - val_loss: 0.3775 - val_accuracy: 0.8429
# Epoch 8/3000
# 210/210 [==============================] - 3s 12ms/step - loss: 0.3627 - accuracy: 0.8504 - val_loss: 0.3862 - val_accuracy: 0.8450
# Epoch 9/3000
# 210/210 [==============================] - 3s 12ms/step - loss: 0.3592 - accuracy: 0.8506 - val_loss: 0.3821 - val_accuracy: 0.8498
# Epoch 10/3000
# 210/210 [==============================] - 3s 12ms/step - loss: 0.3571 - accuracy: 0.8531 - val_loss: 0.3809 - val_accuracy: 0.8443
# Epoch 11/3000
# 210/210 [==============================] - 2s 11ms/step - loss: 0.3581 - accuracy: 0.8519 - val_loss: 0.3821 - val_accuracy: 0.8380
# Epoch 12/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3555 - accuracy: 0.8534 - val_loss: 0.3778 - val_accuracy: 0.8446
# Epoch 13/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3520 - accuracy: 0.8537 - val_loss: 0.3713 - val_accuracy: 0.8432
# Epoch 14/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3525 - accuracy: 0.8516 - val_loss: 0.4226 - val_accuracy: 0.8387
# Epoch 15/3000
# 210/210 [==============================] - 2s 10ms/step - loss: 0.3518 - accuracy: 0.8540 - val_loss: 0.3783 - val_accuracy: 0.8485
# Epoch 16/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3525 - accuracy: 0.8522 - val_loss: 0.3787 - val_accuracy: 0.8488
# Epoch 17/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3525 - accuracy: 0.8513 - val_loss: 0.3679 - val_accuracy: 0.8415
# Epoch 18/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3521 - accuracy: 0.8521 - val_loss: 0.3704 - val_accuracy: 0.8488
# Epoch 19/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3506 - accuracy: 0.8558 - val_loss: 0.3874 - val_accuracy: 0.8366
# Epoch 20/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3504 - accuracy: 0.8544 - val_loss: 0.3760 - val_accuracy: 0.8425
# Epoch 21/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3508 - accuracy: 0.8537 - val_loss: 0.3618 - val_accuracy: 0.8505
# Epoch 22/3000
# 210/210 [==============================] - 2s 10ms/step - loss: 0.3493 - accuracy: 0.8543 - val_loss: 0.3636 - val_accuracy: 0.8467
# Epoch 23/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3496 - accuracy: 0.8528 - val_loss: 0.3754 - val_accuracy: 0.8498
# Epoch 24/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3501 - accuracy: 0.8532 - val_loss: 0.3673 - val_accuracy: 0.8460
# Epoch 25/3000
# 210/210 [==============================] - 2s 10ms/step - loss: 0.3466 - accuracy: 0.8549 - val_loss: 0.3792 - val_accuracy: 0.8471
# Epoch 26/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3485 - accuracy: 0.8541 - val_loss: 0.3634 - val_accuracy: 0.8471
# Epoch 27/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3477 - accuracy: 0.8547 - val_loss: 0.3865 - val_accuracy: 0.8488
# Epoch 28/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3475 - accuracy: 0.8552 - val_loss: 0.3668 - val_accuracy: 0.8478
# Epoch 29/3000
# 210/210 [==============================] - 2s 10ms/step - loss: 0.3469 - accuracy: 0.8562 - val_loss: 0.3724 - val_accuracy: 0.8495
# Epoch 30/3000
# 210/210 [==============================] - 2s 10ms/step - loss: 0.3466 - accuracy: 0.8540 - val_loss: 0.3707 - val_accuracy: 0.8453
# Epoch 31/3000
# 210/210 [==============================] - 2s 10ms/step - loss: 0.3465 - accuracy: 0.8558 - val_loss: 0.3679 - val_accuracy: 0.8453
# Epoch 32/3000
# 210/210 [==============================] - 2s 10ms/step - loss: 0.3465 - accuracy: 0.8558 - val_loss: 0.3939 - val_accuracy: 0.8439
# Epoch 33/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3459 - accuracy: 0.8546 - val_loss: 0.3788 - val_accuracy: 0.8467
# Epoch 34/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3457 - accuracy: 0.8555 - val_loss: 0.3687 - val_accuracy: 0.8481
# Epoch 35/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3451 - accuracy: 0.8541 - val_loss: 0.3715 - val_accuracy: 0.8429
# Epoch 36/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3436 - accuracy: 0.8585 - val_loss: 0.3705 - val_accuracy: 0.8502
# Epoch 37/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3441 - accuracy: 0.8582 - val_loss: 0.3738 - val_accuracy: 0.8488
# Epoch 38/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3476 - accuracy: 0.8573 - val_loss: 0.3756 - val_accuracy: 0.8432
# Epoch 39/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3426 - accuracy: 0.8555 - val_loss: 0.3860 - val_accuracy: 0.8457
# Epoch 40/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3438 - accuracy: 0.8577 - val_loss: 0.3721 - val_accuracy: 0.8443
# Epoch 41/3000
# 210/210 [==============================] - 2s 9ms/step - loss: 0.3419 - accuracy: 0.8583 - val_loss: 0.3666 - val_accuracy: 0.8464
# Epoch 41: early stopping

# %%
# let's plot the training and validation loss
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# Evaluating the network
_, accuracy = model.evaluate(X_train, y_train)
print("Model accuracy: %.2f"% (accuracy*100))
# Out:
# 210/210 [==============================] - 1s 6ms/step - loss: 0.3406 - accuracy: 0.8558
# Model accuracy: 85.58
