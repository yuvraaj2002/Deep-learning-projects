# %% [markdown]
# # Step 1: Installing the dependencies
#
# - The first import statement imports the warnings module, which provides functions for managing warnings in Python programs. The second line warnings.filterwarnings("ignore") sets a filter to ignore all warnings. This is often done to suppress unnecessary warning messages.
#
# - The next few lines import modules for working with files and directories in Python. os provides a way to interact with the operating system, shutil provides high-level file operations, and glob is used to find files that match a specified pattern.
#
# - The cv2 module is part of the OpenCV library, which is a popular library for computer vision tasks in Python. It is used for reading, manipulating and writing image files.
#
# - The time module provides functions for working with time, such as measuring the time elapsed between two points in a program.
#
# - The uuid module provides functions for creating universally unique identifiers (UUIDs), which are used for uniquely identifying objects or entities.
#
# - The torch module is a popular deep learning framework for Python. It is commonly used for tasks such as training and evaluating neural networks.
#
# - The tensorflow module is another popular deep learning framework for Python, developed by Google. It provides a comprehensive ecosystem of tools and libraries for building and deploying machine learning models.
#
# - The json module is used for encoding and decoding JSON data in Python.
#
# - The numpy module is a popular library for numerical computing in Python. It provides efficient array operations and mathematical functions for working with large datasets.
#
# - The matplotlib module is a popular data visualization library for Python. %matplotlib inline is a magic command that is used in Jupyter notebooks to display plots inline.
#
# - Finally, from tensorflow.keras.models import load_model imports the load_model function from the tensorflow.keras.models module. This function is used to load a saved Keras model from disk.

# %%
# For Ignoring all warnings
import warnings
warnings.filterwarnings("ignore")

# For working with files
import os 
import shutil
import glob
import cv2
import time
import uuid # For creating a uniform unique identifier

import torch
import tensorflow as tf
import json
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from tensorflow.keras.models import load_model

# %% [markdown]
# # Step 2: Collecting images using opencv

# %% [markdown]
# First of all before collecting the images from our webcam. We need to specify the folder in which we will be collecting our images.

# %%
# Now specifying the number of images we will collect
Num_img = 25

# %%
# Create a VideoCapture object to access the default camera
cap = cv2.VideoCapture(0)

# Check if the camera is opened successfully
if not cap.isOpened():
    print("Cannot open camera")
    exit()

# Loop to read frames from the camera and display them in a window
for img in range(3):
    print('Collecting image {}'.format(img))
    ret,frame = cap.read()
    
     # If the frame is not read correctly, break the loop
    if not ret:
        print("Cannot receive frame")
        break
        
    img_name = os.path.join('data','images',f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(img_name,frame)
    cv2.imshow('frame',frame)
    time.sleep(0.5)
    
    # Wait for 1 millisecond and check if the user pressed the 'q' key to quit
    if cv2.waitKey(1) == ord('q'):
        break


# Release the VideoCapture object and close the window
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Step 3: Annotating the images with LabelMe

# %%
# Let's launch Labelme annotation tool for annotating the images
# !labelme
# Out:
# qt.qpa.fonts: Unable to open default EUDC font: "EUDC.TTE"

# %% [markdown]
# # Step 4: Creating a pipeline

# %% [markdown]
# By setting the memory growth option, TensorFlow will only allocate memory on the GPU as it is needed during training, rather than reserving the entire GPU memory at the start of the program. This can help to optimize memory usage and prevent out-of-memory errors.

# %%
# First to limit the GPU growht we will try to avoid the OOM errors by setting GPU memory consumption growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)

# %%
# Let's check if GPU is present or not
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### 4.1 Loading image data to tensorflow datasets
#
# The below mentioned code will create a TensorFlow dataset of image file paths using the tf.data.Dataset.list_files() function. The resulting dataset Images will contain a list of file paths to the images in the specified directory which further could be use to load an image.
#
# #### Arguments
# **data\\images\\*.jpg**: *A string specifying the file path pattern to match image files. In this case, the pattern matches all .jpg files located in the data/images directory. The double backslashes \\ are used to escape the backslash character and prevent it from being interpreted as an escape sequence.
#
# **shuffle=False**: *A boolean specifying whether to shuffle the file paths. By default, list_files() shuffles the file paths, which can be useful for randomizing the order of training data. However, in some cases, such as when you want to ensure reproducibility, it may be necessary to disable shuffling. Here, shuffle=False disables shuffling.*
#
# #### Returns
# The **tf.data.Dataset.list_files()** *function returns a TensorFlow dataset containing a list of file paths matching the specified pattern. The dataset can be used to load the actual image data later on in the data processing pipeline.*

# %%
# Let's create a tensorflow dataset of image paths
Images = tf.data.Dataset.list_files('data\\images\\*.jpg',shuffle=False)

# %% [markdown]
# Now in order to load the image from the file path let's create a function

# %%
# Function to load the image
def load_img(x):
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# Let's apply load_img function on every file path stored in Images tensorflow dataset
Images = Images.map(load_img)

# %%
Image_numpy_iterator = Images.batch(5).as_numpy_iterator()
plot_images = Image_numpy_iterator.next()

# %% [markdown]
# **batch() method**
# The batch() method is a method of TensorFlow datasets that groups elements of the dataset into batches. The batch_size argument specifies the number of elements to combine into a single batch. In this case, Images.batch(5) creates a new dataset that groups images into batches of 5.
#
# **as_numpy_iterator() method**
# The as_numpy_iterator() method is used to convert a TensorFlow dataset to a NumPy iterator that generates batches of elements from the dataset as NumPy arrays. In this case, Image_numpy_iterator is a NumPy iterator that generates batches of 5 image file paths as NumPy arrays.
#
# **next() method**
# The next() method is a method of iterators that returns the next element in the iterator as a NumPy array. In this case, Image_numpy_iterator.next() returns the next batch of 5 image file paths as a NumPy array, which is stored in the plot_images variable.

# %%
# let's plot the images
fig, ax = plt.subplots(ncols=5, figsize=(20,20))

for idx, image in enumerate(plot_images):
    ax[idx].imshow(image) 
plt.show()

# %% [markdown]
# # Step 4: Data augmentation
#
# To better understand how does everything works refer this documentation https://albumentations.ai/docs/introduction/image_augmentation/

# %%
# After manually seperating the labels we will now move labels to their respective images
for folder in ['train','test','val']:
    for file in os.listdir(os.path.join('data',folder,'images')):
        
        filename = file.split('.')[0]+'.json'
        existing_filepath = os.path.join('data','labels', filename)
        if os.path.exists(existing_filepath): 
            new_filepath = os.path.join('data',folder,'labels',filename)
            os.replace(existing_filepath, new_filepath)

# %% [markdown]
# Now we will synthetically generate more data using the concept of data augmentation, at the same time we will also augment the labels also using library called Albumentations.

# %%
import albumentations as alb

# %%
augmentor = alb.Compose([alb.RandomCrop(width=450, height=450), 
                         alb.HorizontalFlip(p=0.5), 
                         alb.RandomBrightnessContrast(p=0.2),
                         alb.RandomGamma(p=0.2), 
                         alb.RGBShift(p=0.2), 
                         alb.VerticalFlip(p=0.5)], 
                       bbox_params=alb.BboxParams(format='albumentations', 
                                                  label_fields=['class_labels']))

# %% [markdown]
# ## Understand the working albumentation using single image

# %%
img = cv2.imread(os.path.join('data','train', 'images','21817f30-c998-11ed-a79b-48e7da5d1fec.jpg'))

with open(os.path.join('data', 'train', 'labels', '21817f30-c998-11ed-a79b-48e7da5d1fec.json'), 'r') as f:
    label = json.load(f)

# %%
# label['shapes'][0]['points']
# Out:
# [[231.0, 85.0], [407.0, 346.0]]

# %%
# Let's extract the coordinates form the dictionary
coords = [0,0,0,0]
coords[0] = label['shapes'][0]['points'][0][0]
coords[1] = label['shapes'][0]['points'][0][1]
coords[2] = label['shapes'][0]['points'][1][0]
coords[3] = label['shapes'][0]['points'][1][1]

# %%
# Let's normalize the coordinates to work with albumentation library
coords = list(np.divide(coords, [640,480,640,480]))

# %%
augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])

# %%
cv2.rectangle(augmented['image'], 
              tuple(np.multiply(augmented['bboxes'][0][:2], [450,450]).astype(int)),
              tuple(np.multiply(augmented['bboxes'][0][2:], [450,450]).astype(int)), 
                    (255,0,0), 2)

plt.imshow(augmented['image'])

# %% [markdown]
# # Data augmentation pipeline

# %% [markdown]
# Now let's create a data augmnetation pipeline

# %%
for folder in ['train','test','val']: 
    for image in os.listdir(os.path.join('data', folder, 'images')):
        img = cv2.imread(os.path.join('data', folder, 'images', image)) # Reading an image

        # We have initialized a list having coordinate values in the case there is no face in the image
        coords = [0,0,0.00001,0.00001]
        label_path = os.path.join('data', folder, 'labels', f'{image.split(".")[0]}.json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)

            # Storing the coordinates from the label dictionary, corrdinates are : X_min,Y_min,X_max,Y_max
            coords[0] = label['shapes'][0]['points'][0][0] 
            coords[1] = label['shapes'][0]['points'][0][1]
            coords[2] = label['shapes'][0]['points'][1][0]
            coords[3] = label['shapes'][0]['points'][1][1]
            coords = list(np.divide(coords, [640,480,640,480])) # Nomalizing the coordinate values

        try: 
            for x in range(60): # From a base image we will create 60 augmented images
                augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                
                # We will store the augmented images in the below mentioned folder
                cv2.imwrite(os.path.join('Aug_data', folder, 'images', f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])

                annotation = {}
                annotation['image'] = image

                if os.path.exists(label_path):
                    if len(augmented['bboxes']) == 0: 
                        annotation['bbox'] = [0,0,0,0]
                        annotation['class'] = 0 
                    else: 
                        annotation['bbox'] = augmented['bboxes'][0]
                        annotation['class'] = 1
                else: 
                    annotation['bbox'] = [0,0,0,0]
                    annotation['class'] = 0 


                with open(os.path.join('Aug_data', folder, 'labels', f'{image.split(".")[0]}.{x}.json'), 'w') as f:
                    json.dump(annotation, f)

        except Exception as e:
            print(e)

# %% [markdown]
# # Load Augmented Images to Tensorflow Dataset

# %% [markdown]
# The below mentioned function takes a file path as input, reads the contents of the file into a tensor, and decodes the tensor into an image format that TensorFlow can work with (in this case, a JPEG image with 3 color channels).

# %%
def load_image(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    return img

# %%
train_images = tf.data.Dataset.list_files('Aug_data\\train\\images\\*.jpg', shuffle=False)
train_images = train_images.map(load_image)
train_images = train_images.map(lambda x: tf.image.resize(x, (120,120)))
train_images = train_images.map(lambda x: x/255)

# %%
test_images = tf.data.Dataset.list_files('Aug_data\\test\\images\\*.jpg', shuffle=False)
test_images = test_images.map(load_image)
test_images = test_images.map(lambda x: tf.image.resize(x, (120,120)))
test_images = test_images.map(lambda x: x/255)

# %%
val_images = tf.data.Dataset.list_files('Aug_data\\val\\images\\*.jpg', shuffle=False)
val_images = val_images.map(load_image)
val_images = val_images.map(lambda x: tf.image.resize(x, (120,120)))
val_images = val_images.map(lambda x: x/255)

# %%
# Creating a function to extract class and bounding box coordinates
def load_labels(label_path):
    with open(label_path.numpy(), 'r', encoding = "utf-8") as f:
        label = json.load(f)
        
    return [label['class']], label['bbox']

# %%
# Let's load the labels into tensorflow dataset
train_labels = tf.data.Dataset.list_files('Aug_data\\train\\labels\\*.json', shuffle=False)
train_labels = train_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

test_labels = tf.data.Dataset.list_files('Aug_data\\test\\labels\\*.json', shuffle=False)
test_labels = test_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

val_labels = tf.data.Dataset.list_files('Aug_data\\val\\labels\\*.json', shuffle=False)
val_labels = val_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
len(train_images), len(train_labels), len(test_images), len(test_labels), len(val_images), len(val_labels)
# Out:
# (3000, 3000, 600, 600, 600, 600)

# %%
# Let's create a final dataset
train = tf.data.Dataset.zip((train_images, train_labels))
train = train.shuffle(4000)
train = train.batch(8)
train = train.prefetch(4)

test = tf.data.Dataset.zip((test_images, test_labels))
test = test.shuffle(1200)
test = test.batch(8)
test = test.prefetch(4)

val = tf.data.Dataset.zip((val_images, val_labels))
val = val.shuffle(1200)
val = val.batch(8)
val = val.prefetch(4)

# %% [markdown]
# # Deep learning model

# %%
# For installing pytorch
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117

# %%
# Importing layers and base network
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16

# Downloading VGG16 model
vgg = VGG16(include_top=False)

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Let's now build the model
def build_model(): 
    input_layer = Input(shape=(120,120,3))
    
    vgg = VGG16(include_top=False)(input_layer)

    # Classification Model  
    f1 = GlobalMaxPooling2D()(vgg)
    class1 = Dense(2048, activation='relu')(f1)
    class2 = Dense(1, activation='sigmoid')(class1)
    
    # Bounding box model
    f2 = GlobalMaxPooling2D()(vgg)
    regress1 = Dense(2048, activation='relu')(f2)
    regress2 = Dense(4, activation='sigmoid')(regress1)
    
    facetracker = Model(inputs=input_layer, outputs=[class2, regress2])
    return facetracker

# %%
facetracker = build_model()
facetracker.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 120, 120, 3  0           []
#                                 )]
#
#  vgg16 (Functional)             (None, None, None,   14714688    ['input_2[0][0]']
#                                 512)
#
#  global_max_pooling2d (GlobalMa  (None, 512)         0           ['vgg16[0][0]']
#  xPooling2D)
#
#  global_max_pooling2d_1 (Global  (None, 512)         0           ['vgg16[0][0]']
#  MaxPooling2D)
#
#  dense (Dense)                  (None, 2048)         1050624     ['global_max_pooling2d[0][0]']
#
#  dense_2 (Dense)                (None, 2048)         1050624     ['global_max_pooling2d_1[0][0]']
#
#  dense_1 (Dense)                (None, 1)            2049        ['dense[0][0]']
#
#  dense_3 (Dense)                (None, 4)            8196        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 16,826,181
# Trainable params: 16,826,181
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Defining loss and optimizers

# %%
batches_per_epoch = len(train)
lr_decay = (1./0.75 -1)/batches_per_epoch
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=lr_decay)

# %%
def localization_loss(y_true, yhat):            
    delta_coord = tf.reduce_sum(tf.square(y_true[:,:2] - yhat[:,:2]))
                  
    h_true = y_true[:,3] - y_true[:,1] 
    w_true = y_true[:,2] - y_true[:,0] 

    h_pred = yhat[:,3] - yhat[:,1] 
    w_pred = yhat[:,2] - yhat[:,0] 
    
    delta_size = tf.reduce_sum(tf.square(w_true - w_pred) + tf.square(h_true-h_pred))
    
    return delta_coord + delta_size

# %%
classloss = tf.keras.losses.BinaryCrossentropy()
regressloss = localization_loss

# %%
class FaceTracker(Model): 
    def __init__(self, eyetracker,  **kwargs): 
        super().__init__(**kwargs)
        self.model = eyetracker

    def compile(self, opt, classloss, localizationloss, **kwargs):
        super().compile(**kwargs)
        self.closs = classloss
        self.lloss = localizationloss
        self.opt = opt
    
    def train_step(self, batch, **kwargs): 
        
        X, y = batch
        
        with tf.GradientTape() as tape: 
            classes, coords = self.model(X, training=True)
            
            batch_classloss = self.closs(y[0], classes)
            batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
            
            total_loss = batch_localizationloss+0.5*batch_classloss
            
            grad = tape.gradient(total_loss, self.model.trainable_variables)
        
        opt.apply_gradients(zip(grad, self.model.trainable_variables))
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
    
    def test_step(self, batch, **kwargs): 
        X, y = batch
        
        classes, coords = self.model(X, training=False)
        
        batch_classloss = self.closs(y[0], classes)
        batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
        total_loss = batch_localizationloss+0.5*batch_classloss
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
        
    def call(self, X, **kwargs): 
        return self.model(X, **kwargs)

# %%
model = FaceTracker(facetracker)
model.compile(opt, classloss, regressloss)

# %% [markdown]
# # Training the model

# %%
logdir='logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train, epochs=40, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/40
# 375/375 [==============================] - 56s 129ms/step - total_loss: 0.0599 - class_loss: 0.0176 - regress_loss: 0.0511 - val_total_loss: 0.0190 - val_class_loss: 0.0046 - val_regress_loss: 0.0167
# Epoch 2/40
# 375/375 [==============================] - 53s 128ms/step - total_loss: 0.0128 - class_loss: 0.0018 - regress_loss: 0.0119 - val_total_loss: 0.0133 - val_class_loss: 3.6558e-04 - val_regress_loss: 0.0131
# Epoch 3/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0067 - class_loss: 3.2672e-04 - regress_loss: 0.0065 - val_total_loss: 0.0307 - val_class_loss: 1.7295e-04 - val_regress_loss: 0.0306
# Epoch 4/40
# 375/375 [==============================] - 53s 129ms/step - total_loss: 0.0045 - class_loss: 1.2149e-04 - regress_loss: 0.0044 - val_total_loss: 0.0173 - val_class_loss: 1.7889e-05 - val_regress_loss: 0.0173
# Epoch 5/40
# 375/375 [==============================] - 53s 128ms/step - total_loss: 0.0036 - class_loss: 8.0127e-05 - regress_loss: 0.0035 - val_total_loss: 0.0075 - val_class_loss: 2.3515e-05 - val_regress_loss: 0.0075
# Epoch 6/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0037 - class_loss: 6.3092e-05 - regress_loss: 0.0036 - val_total_loss: 0.0057 - val_class_loss: 4.4984e-05 - val_regress_loss: 0.0056
# Epoch 7/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0030 - class_loss: 5.4358e-05 - regress_loss: 0.0030 - val_total_loss: 0.0100 - val_class_loss: 9.9839e-06 - val_regress_loss: 0.0099
# Epoch 8/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0029 - class_loss: 5.0449e-05 - regress_loss: 0.0028 - val_total_loss: 0.0112 - val_class_loss: 5.1856e-06 - val_regress_loss: 0.0112
# Epoch 9/40
# 375/375 [==============================] - 53s 129ms/step - total_loss: 0.0026 - class_loss: 4.1811e-05 - regress_loss: 0.0026 - val_total_loss: 0.0032 - val_class_loss: 1.3717e-05 - val_regress_loss: 0.0032
# Epoch 10/40
# 375/375 [==============================] - 53s 129ms/step - total_loss: 0.0025 - class_loss: 3.3433e-05 - regress_loss: 0.0025 - val_total_loss: 0.0054 - val_class_loss: 1.1268e-04 - val_regress_loss: 0.0053
# Epoch 11/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0030 - class_loss: 3.6475e-05 - regress_loss: 0.0029 - val_total_loss: 0.0058 - val_class_loss: 3.1995e-05 - val_regress_loss: 0.0058
# Epoch 12/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0026 - class_loss: 3.2663e-05 - regress_loss: 0.0026 - val_total_loss: 0.0025 - val_class_loss: 1.0371e-05 - val_regress_loss: 0.0025
# Epoch 13/40
# 375/375 [==============================] - 52s 127ms/step - total_loss: 0.0022 - class_loss: 2.7094e-05 - regress_loss: 0.0022 - val_total_loss: 0.0088 - val_class_loss: 2.7791e-06 - val_regress_loss: 0.0088
# Epoch 14/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0017 - class_loss: 1.9820e-05 - regress_loss: 0.0017 - val_total_loss: 0.0078 - val_class_loss: 4.0382e-06 - val_regress_loss: 0.0078
# Epoch 15/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0020 - class_loss: 1.7293e-05 - regress_loss: 0.0020 - val_total_loss: 0.0113 - val_class_loss: 7.2718e-06 - val_regress_loss: 0.0113
# Epoch 16/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0022 - class_loss: 1.7706e-05 - regress_loss: 0.0022 - val_total_loss: 0.0116 - val_class_loss: 2.0787e-06 - val_regress_loss: 0.0116
# Epoch 17/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0018 - class_loss: 1.5504e-05 - regress_loss: 0.0018 - val_total_loss: 0.0048 - val_class_loss: 8.3447e-07 - val_regress_loss: 0.0048
# Epoch 18/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0013 - class_loss: 1.0749e-05 - regress_loss: 0.0013 - val_total_loss: 0.0035 - val_class_loss: 3.7030e-06 - val_regress_loss: 0.0035
# Epoch 19/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0015 - class_loss: 1.0334e-05 - regress_loss: 0.0015 - val_total_loss: 0.0174 - val_class_loss: 2.4438e-06 - val_regress_loss: 0.0174
# Epoch 20/40
# 375/375 [==============================] - 52s 127ms/step - total_loss: 0.0015 - class_loss: 9.5254e-06 - regress_loss: 0.0015 - val_total_loss: 0.0070 - val_class_loss: 4.0680e-06 - val_regress_loss: 0.0070
# Epoch 21/40
# 375/375 [==============================] - 52s 129ms/step - total_loss: 0.0015 - class_loss: 8.7298e-06 - regress_loss: 0.0015 - val_total_loss: 0.0106 - val_class_loss: 1.0356e-06 - val_regress_loss: 0.0106
# Epoch 22/40
# 375/375 [==============================] - 53s 128ms/step - total_loss: 0.0012 - class_loss: 6.7129e-06 - regress_loss: 0.0012 - val_total_loss: 0.0117 - val_class_loss: 8.0466e-07 - val_regress_loss: 0.0117
# Epoch 23/40
# 375/375 [==============================] - 52s 127ms/step - total_loss: 0.0013 - class_loss: 6.6174e-06 - regress_loss: 0.0013 - val_total_loss: 0.0031 - val_class_loss: 5.5879e-07 - val_regress_loss: 0.0031
# Epoch 24/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0012 - class_loss: 5.1069e-06 - regress_loss: 0.0012 - val_total_loss: 0.0048 - val_class_loss: 4.3958e-07 - val_regress_loss: 0.0048
# Epoch 25/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0012 - class_loss: 4.1858e-06 - regress_loss: 0.0012 - val_total_loss: 0.0196 - val_class_loss: 1.7732e-06 - val_regress_loss: 0.0196
# Epoch 26/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 0.0010 - class_loss: 4.3488e-06 - regress_loss: 0.0010 - val_total_loss: 0.0084 - val_class_loss: 3.7998e-07 - val_regress_loss: 0.0084
# Epoch 27/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 9.7708e-04 - class_loss: 3.1596e-06 - regress_loss: 9.7550e-04 - val_total_loss: 0.0037 - val_class_loss: 2.4587e-07 - val_regress_loss: 0.0037
# Epoch 28/40
# 375/375 [==============================] - 53s 128ms/step - total_loss: 9.6831e-04 - class_loss: 2.8339e-06 - regress_loss: 9.6689e-04 - val_total_loss: 0.0175 - val_class_loss: 3.3528e-07 - val_regress_loss: 0.0175
# Epoch 29/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 8.3943e-04 - class_loss: 2.4997e-06 - regress_loss: 8.3818e-04 - val_total_loss: 0.0110 - val_class_loss: 8.1956e-08 - val_regress_loss: 0.0110
# Epoch 30/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 9.3858e-04 - class_loss: 2.9970e-06 - regress_loss: 9.3709e-04 - val_total_loss: 0.0077 - val_class_loss: 2.3842e-07 - val_regress_loss: 0.0077
# Epoch 31/40
# 375/375 [==============================] - 52s 127ms/step - total_loss: 6.8010e-04 - class_loss: 2.0893e-06 - regress_loss: 6.7906e-04 - val_total_loss: 0.0080 - val_class_loss: 1.1176e-07 - val_regress_loss: 0.0080
# Epoch 32/40
# 375/375 [==============================] - 52s 127ms/step - total_loss: 7.6061e-04 - class_loss: 1.4046e-06 - regress_loss: 7.5991e-04 - val_total_loss: 0.0182 - val_class_loss: 2.5332e-07 - val_regress_loss: 0.0182
# Epoch 33/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 6.8944e-04 - class_loss: 1.2380e-06 - regress_loss: 6.8882e-04 - val_total_loss: 0.0025 - val_class_loss: 1.1995e-06 - val_regress_loss: 0.0025
# Epoch 34/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 7.7834e-04 - class_loss: 1.1426e-06 - regress_loss: 7.7776e-04 - val_total_loss: 0.0044 - val_class_loss: 2.4736e-06 - val_regress_loss: 0.0044
# Epoch 35/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 7.2253e-04 - class_loss: 9.6250e-07 - regress_loss: 7.2205e-04 - val_total_loss: 0.0042 - val_class_loss: 2.6822e-07 - val_regress_loss: 0.0042
# Epoch 36/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 6.5569e-04 - class_loss: 9.5761e-07 - regress_loss: 6.5521e-04 - val_total_loss: 0.0038 - val_class_loss: 0.0000e+00 - val_regress_loss: 0.0038
# Epoch 37/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 5.2665e-04 - class_loss: 7.0644e-07 - regress_loss: 5.2630e-04 - val_total_loss: 0.0087 - val_class_loss: 1.9372e-07 - val_regress_loss: 0.0087
# Epoch 38/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 6.2584e-04 - class_loss: 6.5938e-07 - regress_loss: 6.2551e-04 - val_total_loss: 0.0039 - val_class_loss: 2.3097e-07 - val_regress_loss: 0.0039
# Epoch 39/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 4.6291e-04 - class_loss: 5.4933e-07 - regress_loss: 4.6264e-04 - val_total_loss: 0.0065 - val_class_loss: 0.0000e+00 - val_regress_loss: 0.0065
# Epoch 40/40
# 375/375 [==============================] - 52s 128ms/step - total_loss: 4.6937e-04 - class_loss: 4.4710e-07 - regress_loss: 4.6914e-04 - val_total_loss: 0.0096 - val_class_loss: 1.4901e-08 - val_regress_loss: 0.0096

# %% [markdown]
# # Plotting the performance

# %%
hist.history
fig, ax = plt.subplots(ncols=3, figsize=(20,5))

ax[0].plot(hist.history['total_loss'], color='teal', label='loss')
ax[0].plot(hist.history['val_total_loss'], color='orange', label='val loss')
ax[0].title.set_text('Loss')
ax[0].legend()

ax[1].plot(hist.history['class_loss'], color='teal', label='class loss')
ax[1].plot(hist.history['val_class_loss'], color='orange', label='val class loss')
ax[1].title.set_text('Classification Loss')
ax[1].legend()

ax[2].plot(hist.history['regress_loss'], color='teal', label='regress loss')
ax[2].plot(hist.history['val_regress_loss'], color='orange', label='val regress loss')
ax[2].title.set_text('Regression Loss')
ax[2].legend()

plt.show()

# %% [markdown]
# # Saving the model

# %%
# let's save the model
facetracker.save('facetracker.h5')

# %%
# Loading the model
facetracker = load_model('facetracker.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # Real time detection

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    _ , frame = cap.read()
    frame = frame[50:500, 50:500,:]
    
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120,120))
    
    yhat = facetracker.predict(np.expand_dims(resized/255,0))
    sample_coords = yhat[1][0]
    
    if yhat[0] > 0.5: 
        # Controls the main rectangle
        cv2.rectangle(frame, 
                      tuple(np.multiply(sample_coords[:2], [450,450]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [450,450]).astype(int)), 
                            (255,0,0), 2)
        # Controls the label rectangle
        cv2.rectangle(frame, 
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int), 
                                    [0,-30])),
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                    [80,0])), 
                            (255,0,0), -1)
        
        # Controls the text rendered
        cv2.putText(frame, 'face', tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                               [0,-5])),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    
    cv2.imshow('EyeTrack', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
